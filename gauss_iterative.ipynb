# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Examen
# ## Gauss-Jacobi y Gauss-Seidel

# %%
# %autoreload 2
from src import eliminacion_gaussiana, matriz_aumentada
A = [[1, 1], [-2, 5]]
b = [7, 0]
eliminacion_gaussiana(matriz_aumentada(A, b))
# Out:
# [07-19 22:47:53][INFO]
# [[ 1.  1.  7.]
#  [ 0.  7. 14.]]
# array([5., 2.])

# %%
import numpy as np
import matplotlib.pyplot as plt
from src import gauss_jacobi, gauss_seidel

# %%
# %autoreload 2
from src import gauss_jacobi
A = [[1, 1], [-2, 5]]
b = [7, 0]
n = len(A)

gauss_jacobi(A=A, b=b, x0=[0]*n, tol=1e-5, max_iter=1000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 7
#       4 b = [7, 0]
#       5 n = len(A)
# ----> 7 gauss_jacobi(A=A, b=b, x0=[0]*n, tol=1e-5, max_iter=1000)
#
# File ~\Documents\Prueba 2\src\iterative_methods.py:44, in gauss_jacobi(A, b, x0, tol, max_iter)
#      29 def gauss_jacobi(
#      30     *, A: np.array, b: np.array, x0: np.array, tol: float, max_iter: int
#      31 ) -> tuple[np.array, list[np.array]]:
#      32     """Resuelve el sistema de ecuaciones lineales Ax = b mediante el método de Jacobi.
#      33
#      34     ## Parameters
#    (...)
#      42     ``x``: Vector solución del sistema de ecuaciones lineales.
#      43     """
# ---> 44     n = A.shape[0]
#      45     x = x0.copy()
#      46     trajectory = [x.copy()]
#
# AttributeError: 'list' object has no attribute 'shape'

# %% [markdown]
# ![alt text](assets/trayectoria.png)

# %% [markdown]
# ## Grafique

# %%
# Datos del sistema de ecuaciones
A = np.array([[1, 1], [-2, 5]], dtype=float)
b = np.array([7, 0], dtype=float).reshape(-1, 1)
x0 = np.array([0, 0], dtype=float).reshape(-1, 1)
tol = 1e-5
max_iter = 1000

# Solución y trayectoria usando Gauss-Jacobi
x_jacobi, traj_jacobi = gauss_jacobi(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)


# Graficar las trayectorias
plt.figure(figsize=(10, 6))

# Trayectoria Gauss-Jacobi
traj_jacobi = np.hstack(traj_jacobi)
plt.plot(traj_jacobi[0, :], traj_jacobi[1, :], 'o-', label='Gauss-Jacobi', color='blue')



# Solución real
plt.plot(5, 2, 's', label='Solución Real', color='green')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.legend()
plt.title('Trayectorias de Gauss-Jacobi')
plt.grid(True)
plt.show()
# Out:
# [07-19 22:47:56][INFO] i= 0 x: [[0. 0.]]
# [07-19 22:47:56][INFO] i= 1 x: [[7. 0.]]
# [07-19 22:47:56][INFO] i= 2 x: [[7.  2.8]]
# [07-19 22:47:56][INFO] i= 3 x: [[4.2 2.8]]
# [07-19 22:47:56][INFO] i= 4 x: [[4.2  1.68]]
# [07-19 22:47:56][INFO] i= 5 x: [[5.32 1.68]]
# [07-19 22:47:56][INFO] i= 6 x: [[5.32  2.128]]
# [07-19 22:47:56][INFO] i= 7 x: [[4.872 2.128]]
# [07-19 22:47:56][INFO] i= 8 x: [[4.872  1.9488]]
# [07-19 22:47:56][INFO] i= 9 x: [[5.0512 1.9488]]
# [07-19 22:47:56][INFO] i= 10 x: [[5.0512  2.02048]]
# [07-19 22:47:56][INFO] i= 11 x: [[4.97952 2.02048]]
# [07-19 22:47:56][INFO] i= 12 x: [[4.97952  1.991808]]
# [07-19 22:47:56][INFO] i= 13 x: [[5.008192 1.991808]]
# [07-19 22:47:56][INFO] i= 14 x: [[5.008192  2.0032768]]
# [07-19 22:47:56][INFO] i= 15 x: [[4.9967232 2.0032768]]
# [07-19 22:47:56][INFO] i= 16 x: [[4.9967232  1.99868928]]
# [07-19 22:47:56][INFO] i= 17 x: [[5.00131072 1.99868928]]
# [07-19 22:47:56][INFO] i= 18 x: [[5.00131072 2.00052429]]
# ...

# %%
# Datos del sistema de ecuaciones
A = np.array([[1, 1], [-2, 5]], dtype=float)
b = np.array([7, 0], dtype=float).reshape(-1, 1)
x0 = np.array([0, 0], dtype=float).reshape(-1, 1)
tol = 1e-5
max_iter = 1000

# Solución y trayectoria usando Gauss-Seidel
x_seidel, traj_seidel = gauss_seidel(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)

# Graficar las trayectorias
plt.figure(figsize=(10, 6))

# Trayectoria Gauss-Seidel
traj_seidel = np.hstack(traj_seidel)
plt.plot(traj_seidel[0, :], traj_seidel[1, :], 'x-', label='Gauss-Seidel', color='red')

# Solución real
plt.plot(5, 2, 's', label='Solución Real', color='green')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.legend()
plt.title('Trayectorias de Gauss-Seidel')
plt.grid(True)
plt.show()
# Out:
# [07-19 22:47:58][INFO] i= 0 x: [[0. 0.]]
# [07-19 22:47:58][INFO] i= 1 x: [[7.  2.8]]
# [07-19 22:47:58][INFO] i= 2 x: [[4.2  1.68]]
# [07-19 22:47:58][INFO] i= 3 x: [[5.32  2.128]]
# [07-19 22:47:58][INFO] i= 4 x: [[4.872  1.9488]]
# [07-19 22:47:58][INFO] i= 5 x: [[5.0512  2.02048]]
# [07-19 22:47:58][INFO] i= 6 x: [[4.97952  1.991808]]
# [07-19 22:47:58][INFO] i= 7 x: [[5.008192  2.0032768]]
# [07-19 22:47:58][INFO] i= 8 x: [[4.9967232  1.99868928]]
# [07-19 22:47:58][INFO] i= 9 x: [[5.00131072 2.00052429]]
# [07-19 22:47:58][INFO] i= 10 x: [[4.99947571 1.99979028]]
# [07-19 22:47:58][INFO] i= 11 x: [[5.00020972 2.00008389]]
# [07-19 22:47:58][INFO] i= 12 x: [[4.99991611 1.99996645]]
# [07-19 22:47:58][INFO] i= 13 x: [[5.00003355 2.00001342]]
# [07-19 22:47:58][INFO] i= 14 x: [[4.99998658 1.99999463]]
# [07-19 22:47:58][INFO] i= 15 x: [[5.00000537 2.00000215]]

# %% [markdown]
# ## Use otra estimación inicial
# $ x_0 = (1, 1)$

# %% [markdown]
# # Grafique

# %% [markdown]
# ## Gauss-Jacobi

# %%
# Datos del sistema de ecuaciones
A = np.array([[1, 1], [-2, 5]], dtype=float)
b = np.array([7, 0], dtype=float).reshape(-1, 1)
x0 = np.array([1, 1], dtype=float).reshape(-1, 1)
tol = 1e-5
max_iter = 1000

# Solución y trayectoria usando Gauss-Jacobi
x_jacobi, traj_jacobi = gauss_jacobi(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)


# Graficar las trayectorias
plt.figure(figsize=(10, 6))

# Trayectoria Gauss-Jacobi
traj_jacobi = np.hstack(traj_jacobi)
plt.plot(traj_jacobi[0, :], traj_jacobi[1, :], 'o-', label='Gauss-Jacobi', color='blue')



# Solución real
plt.plot(5, 2, 's', label='Solución Real', color='green')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.legend()
plt.title('Trayectoria de Gauss-Jacobi')
plt.grid(True)
plt.show()
# Out:
# [07-19 22:48:01][INFO] i= 0 x: [[1. 1.]]
# [07-19 22:48:01][INFO] i= 1 x: [[6.  0.4]]
# [07-19 22:48:01][INFO] i= 2 x: [[6.6 2.4]]
# [07-19 22:48:01][INFO] i= 3 x: [[4.6  2.64]]
# [07-19 22:48:01][INFO] i= 4 x: [[4.36 1.84]]
# [07-19 22:48:01][INFO] i= 5 x: [[5.16  1.744]]
# [07-19 22:48:01][INFO] i= 6 x: [[5.256 2.064]]
# [07-19 22:48:01][INFO] i= 7 x: [[4.936  2.1024]]
# [07-19 22:48:01][INFO] i= 8 x: [[4.8976 1.9744]]
# [07-19 22:48:01][INFO] i= 9 x: [[5.0256  1.95904]]
# [07-19 22:48:01][INFO] i= 10 x: [[5.04096 2.01024]]
# [07-19 22:48:01][INFO] i= 11 x: [[4.98976  2.016384]]
# [07-19 22:48:01][INFO] i= 12 x: [[4.983616 1.995904]]
# [07-19 22:48:01][INFO] i= 13 x: [[5.004096  1.9934464]]
# [07-19 22:48:01][INFO] i= 14 x: [[5.0065536 2.0016384]]
# [07-19 22:48:01][INFO] i= 15 x: [[4.9983616  2.00262144]]
# [07-19 22:48:01][INFO] i= 16 x: [[4.99737856 1.99934464]]
# [07-19 22:48:01][INFO] i= 17 x: [[5.00065536 1.99895142]]
# ...

# %% [markdown]
# ## Gauss-Seidel
# ## Grafique el método de Gauss-Seidel

# %%
# Datos del sistema de ecuaciones
A = np.array([[1, 1], [-2, 5]], dtype=float)
b = np.array([7, 0], dtype=float).reshape(-1, 1)
x0 = np.array([1, 1], dtype=float).reshape(-1, 1)
tol = 1e-5
max_iter = 1000

# Solución y trayectoria usando Gauss-Seidel
x_seidel, traj_seidel = gauss_seidel(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)

# Graficar las trayectorias
plt.figure(figsize=(10, 6))

# Trayectoria Gauss-Seidel
traj_seidel = np.hstack(traj_seidel)
plt.plot(traj_seidel[0, :], traj_seidel[1, :], 'x-', label='Gauss-Seidel', color='red')

# Solución real
plt.plot(5, 2, 's', label='Solución Real', color='green')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.legend()
plt.title('Trayectoria de Gauss-Seidel')
plt.grid(True)
plt.show()
# Out:
# [07-19 22:48:04][INFO] i= 0 x: [[1. 1.]]
# [07-19 22:48:04][INFO] i= 1 x: [[6.  2.4]]
# [07-19 22:48:04][INFO] i= 2 x: [[4.6  1.84]]
# [07-19 22:48:04][INFO] i= 3 x: [[5.16  2.064]]
# [07-19 22:48:04][INFO] i= 4 x: [[4.936  1.9744]]
# [07-19 22:48:04][INFO] i= 5 x: [[5.0256  2.01024]]
# [07-19 22:48:04][INFO] i= 6 x: [[4.98976  1.995904]]
# [07-19 22:48:04][INFO] i= 7 x: [[5.004096  2.0016384]]
# [07-19 22:48:04][INFO] i= 8 x: [[4.9983616  1.99934464]]
# [07-19 22:48:04][INFO] i= 9 x: [[5.00065536 2.00026214]]
# [07-19 22:48:04][INFO] i= 10 x: [[4.99973786 1.99989514]]
# [07-19 22:48:04][INFO] i= 11 x: [[5.00010486 2.00004194]]
# [07-19 22:48:04][INFO] i= 12 x: [[4.99995806 1.99998322]]
# [07-19 22:48:04][INFO] i= 13 x: [[5.00001678 2.00000671]]
# [07-19 22:48:04][INFO] i= 14 x: [[4.99999329 1.99999732]]
# [07-19 22:48:04][INFO] i= 15 x: [[5.00000268 2.00000107]]

# %% [markdown]
# # Resuelva
#
# $ x_1 + x_2 = 6$
#
# $  -2 x_1 +  x_2 = 0$

# %%
# Datos del sistema de ecuaciones
A = np.array([[1, 1], [-2, 1]], dtype=float)
b = np.array([6, 0], dtype=float).reshape(-1, 1)
x0 = np.array([0, 0], dtype=float).reshape(-1, 1)  # Punto inicial
tol = 1e-5
max_iter = 1000

# Solución y trayectoria usando Gauss-Jacobi
x_jacobi, traj_jacobi = gauss_jacobi(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)

# Graficar las trayectorias
plt.figure(figsize=(10, 6))

# Trayectoria Gauss-Jacobi
traj_jacobi = np.hstack(traj_jacobi)
plt.plot(traj_jacobi[0, :], traj_jacobi[1, :], 'o-', label='Gauss-Jacobi', color='blue')

# Solución real
plt.plot(2, 4, 's', label='Solución Real', color='green')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.legend()
plt.title('Trayectoria de Gauss-Jacobi')
plt.grid(True)
plt.show()
# Out:
# [07-19 22:51:30][INFO] i= 0 x: [[0. 0.]]
# [07-19 22:51:30][INFO] i= 1 x: [[6. 0.]]
# [07-19 22:51:30][INFO] i= 2 x: [[ 6. 12.]]
# [07-19 22:51:30][INFO] i= 3 x: [[-6. 12.]]
# [07-19 22:51:30][INFO] i= 4 x: [[ -6. -12.]]
# [07-19 22:51:30][INFO] i= 5 x: [[ 18. -12.]]
# [07-19 22:51:30][INFO] i= 6 x: [[18. 36.]]
# [07-19 22:51:30][INFO] i= 7 x: [[-30.  36.]]
# [07-19 22:51:30][INFO] i= 8 x: [[-30. -60.]]
# [07-19 22:51:30][INFO] i= 9 x: [[ 66. -60.]]
# [07-19 22:51:30][INFO] i= 10 x: [[ 66. 132.]]
# [07-19 22:51:30][INFO] i= 11 x: [[-126.  132.]]
# [07-19 22:51:30][INFO] i= 12 x: [[-126. -252.]]
# [07-19 22:51:30][INFO] i= 13 x: [[ 258. -252.]]
# [07-19 22:51:30][INFO] i= 14 x: [[258. 516.]]
# [07-19 22:51:30][INFO] i= 15 x: [[-510.  516.]]
# [07-19 22:51:30][INFO] i= 16 x: [[ -510. -1020.]]
# [07-19 22:51:30][INFO] i= 17 x: [[ 1026. -1020.]]
# [07-19 22:51:30][INFO] i= 18 x: [[1026. 2052.]]
# [07-19 22:51:30][INFO] i= 19 x: [[-2046.  2052.]]
# ...

# %%
# Datos del sistema de ecuaciones
A = np.array([[1, 1], [-2, 1]], dtype=float)
b = np.array([6, 0], dtype=float).reshape(-1, 1)
x0 = np.array([0, 0], dtype=float).reshape(-1, 1)  # Punto inicial
tol = 1e-5
max_iter = 1000

# Solución y trayectoria usando Gauss-Seidel
x_seidel, traj_seidel = gauss_seidel(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)

# Graficar las trayectorias
plt.figure(figsize=(10, 6))

# Trayectoria Gauss-Seidel
traj_seidel = np.hstack(traj_seidel)
plt.plot(traj_seidel[0, :], traj_seidel[1, :], 'x-', label='Gauss-Seidel', color='red')

# Solución real
plt.plot(2, 4, 's', label='Solución Real', color='green')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.legend()
plt.title('Trayectoria de Gauss-Seidel')
plt.grid(True)
plt.show()
# Out:
# [07-19 22:51:19][INFO] i= 0 x: [[0. 0.]]
# [07-19 22:51:19][INFO] i= 1 x: [[ 6. 12.]]
# [07-19 22:51:19][INFO] i= 2 x: [[ -6. -12.]]
# [07-19 22:51:19][INFO] i= 3 x: [[18. 36.]]
# [07-19 22:51:19][INFO] i= 4 x: [[-30. -60.]]
# [07-19 22:51:19][INFO] i= 5 x: [[ 66. 132.]]
# [07-19 22:51:19][INFO] i= 6 x: [[-126. -252.]]
# [07-19 22:51:19][INFO] i= 7 x: [[258. 516.]]
# [07-19 22:51:19][INFO] i= 8 x: [[ -510. -1020.]]
# [07-19 22:51:19][INFO] i= 9 x: [[1026. 2052.]]
# [07-19 22:51:19][INFO] i= 10 x: [[-2046. -4092.]]
# [07-19 22:51:19][INFO] i= 11 x: [[4098. 8196.]]
# [07-19 22:51:19][INFO] i= 12 x: [[ -8190. -16380.]]
# [07-19 22:51:19][INFO] i= 13 x: [[16386. 32772.]]
# [07-19 22:51:19][INFO] i= 14 x: [[-32766. -65532.]]
# [07-19 22:51:19][INFO] i= 15 x: [[ 65538. 131076.]]
# [07-19 22:51:19][INFO] i= 16 x: [[-131070. -262140.]]
# [07-19 22:51:19][INFO] i= 17 x: [[262146. 524292.]]
# [07-19 22:51:19][INFO] i= 18 x: [[ -524286. -1048572.]]
# ...

# %% [markdown]
# Los métodos pueden no llegar a la solución esperada debido a la estructura de la matriz de coeficientes, la elección de condiciones iniciales, o problemas en la implementación. Sin la propiedad de diagonalmente dominante para Gauss-Jacobi, o sin la correcta aplicación de Gauss-Seidel, la convergencia no está garantizada.
